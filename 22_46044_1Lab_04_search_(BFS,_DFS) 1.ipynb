# %% [markdown]
# A Sample graph

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Storing the Graph in a suitable Python data structure**

# %%
example1 = {'S':{'A':1,'B':5},
            'A':{'B':2,'C':3,'D':4},
            'B':{'D':3,'E':3},
            'C':{'B':4,'F':5},
            'D':{'F':6},
            'E':{'D':6,'G':10},
            'F':{'G':5},
            'G':{}
            }

# %% [markdown]
# # Implementation of Breadth First Search (BFS)

# %% [markdown]
# <p style="text-align: justify"> <b>Generated</b> is a set of states which has been generated, because once we’ve reached a state, we can never find a better path to the state. That also means we can do an <b>early goal test</b>, checking whether a node is a solution as soon as it is generated, rather than the late goal test that best-first search uses, waiting until a node is popped off (selected for expansion) the queue.</p>
# <b>Expanded</b> is a set of states which has been <b>selected</b> from the <b>generated</b> list and then expanded.

# %%
def bfs(start, goal, G):
    # by default the expanded list is empty
    expanded= []

    # we don't store only node names rather the paths to the nodes and path costs are also stored
    queue = [([start], 0)]

    # repeat untill the goal test satisfied or the queue becomes empty
    while len(queue) > 0:
        print('\nList of paths in the Queue:')
        for node in queue: print(node[0])

        # selceting the node
        unode  = queue.pop(0)
        u = unode[0][-1]

        if u in expanded: continue
        # expand u
        print(f"\n\nExpanding the path: {unode[0]}")
        expanded.append(u)
        for v in G[u].keys(): # ['Sibiu', 'Zerind', 'Timisoara']
            # process if v is not EXPANDED yet
            if v not in expanded:

              print(f"<{v}> generated! ", end='')
              newPath = unode[0]+[v]
              newCost = unode[1] + G[u][v] #remember the formula g(n')=g(n)+c(n,n')

              # goal test
              if v == goal:
                print('Goal test satisfied.')
                return newPath,newCost # breaking from while

              # if v is not a goal node insert in queue
              queue.append((newPath,newCost))# store the generated node in the frontier

    print('Failed')

# %%
bfs('S', 'G', example1) # change the soure and destination
# Out:
# List of paths in the Queue:
# ['S']
#
#
# Expanding the path: ['S']
# <A> generated! <B> generated!
# List of paths in the Queue:
# ['S', 'A']
# ['S', 'B']
#
#
# Expanding the path: ['S', 'A']
# <B> generated! <C> generated! <D> generated!
# List of paths in the Queue:
# ['S', 'B']
# ['S', 'A', 'B']
# ['S', 'A', 'C']
# ['S', 'A', 'D']
#
#
# Expanding the path: ['S', 'B']
# <D> generated! <E> generated!
# List of paths in the Queue:
# ['S', 'A', 'B']
# ['S', 'A', 'C']
# ['S', 'A', 'D']
# ['S', 'B', 'D']
# ['S', 'B', 'E']
#
# List of paths in the Queue:
# ['S', 'A', 'C']
# ['S', 'A', 'D']
# ['S', 'B', 'D']
# ['S', 'B', 'E']
#
#
# Expanding the path: ['S', 'A', 'C']
# <F> generated!
# List of paths in the Queue:
# ['S', 'A', 'D']
# ['S', 'B', 'D']
# ['S', 'B', 'E']
# ['S', 'A', 'C', 'F']
#
#
# Expanding the path: ['S', 'A', 'D']
# <F> generated!
# List of paths in the Queue:
# ['S', 'B', 'D']
# ['S', 'B', 'E']
# ['S', 'A', 'C', 'F']
# ['S', 'A', 'D', 'F']
#
# ...

# %% [markdown]
# Based on the above BFS simulation, draw the search tree on paper and insert the image in this cell. (Double Click to edit this cell) <br>
# **Image size must be 500 pixel (Horizonal)**

# %% [markdown]
# # DFS
# Implement DFS using stack,
# Implement stack using list (append and pop)

# %%
# modify the code of BFS to inplement DFS
# there will be 3 changes:
# 1) instead of queue a stack will be used
# 2) goal test will be performed for selected node before expanding
example1 = {'S':{'A':1,'B':5},
            'A':{'B':2,'C':3,'D':4},
            'B':{'D':3,'E':3},
            'C':{'B':4,'F':5},
            'D':{'F':6},
            'E':{'D':6,'G':10},
            'F':{'G':5},
            'G':{}
            }

def dfs(start, goal, G):
    # by default the expanded list is empty
    expanded= []

    # we don't store only node names rather the paths to the nodes and path costs are also stored
    stack = [([start], 0)]#unode means full;u=here start;

    # repeat untill the goal test satisfied or the queue becomes empty
    while len(stack) > 0:
        print('\nList of paths in the Queue:')
        for node in stack: print(node[0])

        # selceting the node
        unode  = stack.pop()
        u = unode[0][-1]


        if u in expanded: continue
        # expand u
        print(f"\n\nExpanding the path: {unode[0]}")
        if u == goal:
                print('Goal test satisfied.')
                return unode; # breaking from while
        expanded.append(u)
        for v in G[u].keys(): # ['Sibiu', 'Zerind', 'Timisoara']
            # process if v is not EXPANDED yet
            if v not in expanded:

              print(f"<{v}> generated! ", end='')
              newPath = unode[0]+[v]
              newCost = unode[1] + G[u][v] #remember the formula g(n')=g(n)+c(n,n')

              # goal test

              # if v is not a goal node insert in queue
              stack.append((newPath,newCost))# store the generated node in the frontier

    print('Failed')

# %%
# call DFS here for the Romanian map
dfs('S', 'G', example1)
# Out:
# List of paths in the Queue:
# ['S']
#
#
# Expanding the path: ['S']
# <A> generated! <B> generated!
# List of paths in the Queue:
# ['S', 'A']
# ['S', 'B']
#
#
# Expanding the path: ['S', 'B']
# <D> generated! <E> generated!
# List of paths in the Queue:
# ['S', 'A']
# ['S', 'B', 'D']
# ['S', 'B', 'E']
#
#
# Expanding the path: ['S', 'B', 'E']
# <D> generated! <G> generated!
# List of paths in the Queue:
# ['S', 'A']
# ['S', 'B', 'D']
# ['S', 'B', 'E', 'D']
# ['S', 'B', 'E', 'G']
#
#
# Expanding the path: ['S', 'B', 'E', 'G']
# Goal test satisfied.
# (['S', 'B', 'E', 'G'], 18)

# %% [markdown]
# ![ccb6756f-050c-4d20-99b8-74cc0e7ec3f3.jpg](data:image/jpeg;base64,...)Based on the above DFS simulation, draw the search tree on paper and insert the image in this cell. (**Double Click to edit this cell**)<br>
# **Image size must be 500 pixel (Horizonal)**

# %% [markdown]
# # Another Example

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
romanian_map = {
    'Arad': { 'Zerind':75, 'Timisoara':118, 'Sibiu':140},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %% [markdown]
# In the above graph the start state is **S**, and the goal state is **G**. The transition costs are next to the edges, and the heuristic estimate, h, of the distance from the state to the goal is in the state’s node.
# <br>
# Use **BFS** and  **DFS** for this graph.

# %% [markdown]
# # call BFS here for the above graph

# %%
def bfs(start, goal, G):
    # by default the expanded list is empty
    expanded= []

    # we don't store only node names rather the paths to the nodes and path costs are also stored
    queue = [([start], 0)]

    # repeat untill the goal test satisfied or the queue becomes empty
    while len(queue) > 0:
        print('\nList of paths in the Queue:')
        for node in queue: print(node[0])

        # selceting the node
        unode  = queue.pop(0)
        u = unode[0][-1]

        if u in expanded: continue
        # expand u
        print(f"\n\nExpanding the path: {unode[0]}")
        expanded.append(u)
        for v in G[u].keys(): # ['Sibiu', 'Zerind', 'Timisoara']
            # process if v is not EXPANDED yet
            if v not in expanded:

              print(f"<{v}> generated! ", end='')
              newPath = unode[0]+[v]
              newCost = unode[1] + G[u][v] #remember the formula g(n')=g(n)+c(n,n')

              # goal test
              if v == goal:
                print('Goal test satisfied.')
                return newPath,newCost # breaking from while

              # if v is not a goal node insert in queue
              queue.append((newPath,newCost))# store the generated node in the frontier

    print('Failed');
bfs('Arad', 'Bucharest', romanian_map) # change the soure and destination
# Out:
# List of paths in the Queue:
# ['Arad']
#
#
# Expanding the path: ['Arad']
# <Zerind> generated! <Timisoara> generated! <Sibiu> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind']
# ['Arad', 'Timisoara']
# ['Arad', 'Sibiu']
#
#
# Expanding the path: ['Arad', 'Zerind']
# <Oradea> generated!
# List of paths in the Queue:
# ['Arad', 'Timisoara']
# ['Arad', 'Sibiu']
# ['Arad', 'Zerind', 'Oradea']
#
#
# Expanding the path: ['Arad', 'Timisoara']
# <Lugoj> generated!
# List of paths in the Queue:
# ['Arad', 'Sibiu']
# ['Arad', 'Zerind', 'Oradea']
# ['Arad', 'Timisoara', 'Lugoj']
#
#
# Expanding the path: ['Arad', 'Sibiu']
# <Oradea> generated! <Fagaras> generated! <Rimnicu> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind', 'Oradea']
# ['Arad', 'Timisoara', 'Lugoj']
# ['Arad', 'Sibiu', 'Oradea']
# ['Arad', 'Sibiu', 'Fagaras']
# ['Arad', 'Sibiu', 'Rimnicu']
#
#
# Expanding the path: ['Arad', 'Zerind', 'Oradea']
#
# List of paths in the Queue:
# ...

# %% [markdown]
# Based on the above BFS simulation, draw the search tree on paper and insert the image in this cell. (**Double Click to edit this cell**)![image.png](data:image/png;base64,...)

# %%
# call DFS here for the above graph
def dfs(start, goal, G):
    # by default the expanded list is empty
    expanded= []

    # we don't store only node names rather the paths to the nodes and path costs are also stored
    stack = [([start], 0)]#unode means full;u=here start;

    # repeat untill the goal test satisfied or the queue becomes empty
    while len(stack) > 0:
        print('\nList of paths in the Queue:')
        for node in stack: print(node[0])

        # selceting the node
        unode  = stack.pop()
        u = unode[0][-1]


        if u in expanded: continue
        # expand u
        print(f"\n\nExpanding the path: {unode[0]}")
        if u == goal:
                print('Goal test satisfied.')
                return unode; # breaking from while
        expanded.append(u)
        for v in G[u].keys(): # ['Sibiu', 'Zerind', 'Timisoara']
            # process if v is not EXPANDED yet
            if v not in expanded:

              print(f"<{v}> generated! ", end='')
              newPath = unode[0]+[v]
              newCost = unode[1] + G[u][v] #remember the formula g(n')=g(n)+c(n,n')

              # goal test

              # if v is not a goal node insert in queue
              stack.append((newPath,newCost))# store the generated node in the frontier

    print('Failed')

dfs('Arad', 'Bucharest', romanian_map)
# Out:
# List of paths in the Queue:
# ['Arad']
#
#
# Expanding the path: ['Arad']
# <Zerind> generated! <Timisoara> generated! <Sibiu> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind']
# ['Arad', 'Timisoara']
# ['Arad', 'Sibiu']
#
#
# Expanding the path: ['Arad', 'Sibiu']
# <Oradea> generated! <Fagaras> generated! <Rimnicu> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind']
# ['Arad', 'Timisoara']
# ['Arad', 'Sibiu', 'Oradea']
# ['Arad', 'Sibiu', 'Fagaras']
# ['Arad', 'Sibiu', 'Rimnicu']
#
#
# Expanding the path: ['Arad', 'Sibiu', 'Rimnicu']
# <Craiova> generated! <Pitesti> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind']
# ['Arad', 'Timisoara']
# ['Arad', 'Sibiu', 'Oradea']
# ['Arad', 'Sibiu', 'Fagaras']
# ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']
# ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']
#
#
# Expanding the path: ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']
# <Craiova> generated! <Bucharest> generated!
# List of paths in the Queue:
# ['Arad', 'Zerind']
# ...

# %% [markdown]
# Based on the above DFS simulation, draw the search tree on paper and insert the image in this cell. (**Double Click to edit this cell**)![image.png](data:image/png;base64,...)

# %% [markdown]
# # New Exercise
